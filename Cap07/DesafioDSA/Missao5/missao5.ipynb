# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 7</font>
#
# ## Download: http://github.com/dsacademybr

# %% [markdown]
# ## Missão: Analisar o Comportamento de Compra de Consumidores.

# %% [markdown]
# ## Nível de Dificuldade: Alto

# %% [markdown]
# Você recebeu a tarefa de analisar os dados de compras de um web site! Os dados estão no formato JSON e disponíveis junto com este notebook.
#
# No site, cada usuário efetua login usando sua conta pessoal e pode adquirir produtos à medida que navega pela lista de produtos oferecidos. Cada produto possui um valor de venda. Dados de idade e sexo de cada usuário foram coletados e estão fornecidos no arquivo JSON.
#
# Seu trabalho é entregar uma análise de comportamento de compra dos consumidores. Esse é um tipo de atividade comum realizado por Cientistas de Dados e o resultado deste trabalho pode ser usado, por exemplo, para alimentar um modelo de Machine Learning e fazer previsões sobre comportamentos futuros.
#
# Mas nesta missão você vai analisar o comportamento de compra dos consumidores usando o pacote Pandas da linguagem Python e seu relatório final deve incluir cada um dos seguintes itens:
#
# ** Contagem de Consumidores **
#
# * Número total de consumidores
#
#
# ** Análise Geral de Compras **
#
# * Número de itens exclusivos
# * Preço médio de compra
# * Número total de compras
# * Rendimento total
#
#
# ** Informações Demográficas Por Gênero **
#
# * Porcentagem e contagem de compradores masculinos
# * Porcentagem e contagem de compradores do sexo feminino
# * Porcentagem e contagem de outros / não divulgados
#
#
# ** Análise de Compras Por Gênero **
#
# * Número de compras
# * Preço médio de compra
# * Valor Total de Compra
# * Compras for faixa etária
#
#
# ** Identifique os 5 principais compradores pelo valor total de compra e, em seguida, liste (em uma tabela): **
#
# * Login
# * Número de compras
# * Preço médio de compra
# * Valor Total de Compra
# * Itens mais populares
#
#
# ** Identifique os 5 itens mais populares por contagem de compras e, em seguida, liste (em uma tabela): **
#
# * ID do item
# * Nome do item
# * Número de compras
# * Preço do item
# * Valor Total de Compra
# * Itens mais lucrativos
#
#
# ** Identifique os 5 itens mais lucrativos pelo valor total de compra e, em seguida, liste (em uma tabela): **
#
# * ID do item
# * Nome do item
# * Número de compras
# * Preço do item
# * Valor Total de Compra
#
#
# ** Como considerações finais: **
#
# * Seu script deve funcionar para o conjunto de dados fornecido.
# * Você deve usar a Biblioteca Pandas e o Jupyter Notebook.

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Carrega o arquivo
load_file = "dados_compras.json"
purchase_file = pd.read_json(load_file, orient = "records")
purchase_file.head()
#purchase_file.tail()
# Out:
#    Idade  Item ID         Login                               Nome do Item  \
# 0     38      165     Aelalis34                Bone Crushing Silver Skewer
# 1     21      119        Eolo46  Stormbringer, Dark Blade of Ending Misery
# 2     34      174   Assastnya25                            Primitive Blade
# 3     21       92  Pheusrical25                               Final Critic
# 4     23       63        Aela59                             Stormfury Mace
#
#         Sexo  Valor
# 0  Masculino   3.37
# 1  Masculino   2.32
# 2  Masculino   2.46
# 3  Masculino   1.36
# 4  Masculino   1.27

# %% [markdown]
# ## Informações Sobre os Consumidores

# %%
# Implemente aqui sua solução

# Número total de consumidores
lista_consumidores = list(purchase_file['Login'].values)
lista_geral_consumidores = []
for registro in lista_consumidores:
    if registro not in lista_geral_consumidores:
        lista_geral_consumidores.append(registro)
numero_consumidores = len(lista_geral_consumidores)
numero_consumidores
# Out:
# 573

# %%
dir(pd.DataFrame)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
help(pd.DataFrame.describe)
# Out:
# Help on function describe in module pandas.core.generic:
#
# describe(self, percentiles=None, include=None, exclude=None)
#     Generates descriptive statistics that summarize the central tendency,
#     dispersion and shape of a dataset's distribution, excluding
#     ``NaN`` values.
#
#     Analyzes both numeric and object series, as well
#     as ``DataFrame`` column sets of mixed data types. The output
#     will vary depending on what is provided. Refer to the notes
#     below for more detail.
#
#     Parameters
#     ----------
#     percentiles : list-like of numbers, optional
#         The percentiles to include in the output. All should
#         fall between 0 and 1. The default is
#         ``[.25, .5, .75]``, which returns the 25th, 50th, and
#         75th percentiles.
#     include : 'all', list-like of dtypes or None (default), optional
#         A white list of data types to include in the result. Ignored
#         for ``Series``. Here are the options:
#
# ...

# %% [markdown]
# ## Análise Geral de Compras

# %%
# Implemente aqui sua solução

#Número de itens exclusivos
values = purchase_file['Item ID'].values
lista_valores = list(values)
lista_todos_valores = []
contagem_valores = []
lista_valores_unicos = []
for item in lista_valores:
    if item not in lista_todos_valores:
        lista_todos_valores.append(item)
for item in lista_todos_valores:
    contagem = lista_valores.count(item)
    contagem_valores.append(contagem)
for index,value in enumerate(contagem_valores):
    if value == 1:
        lista_valores_unicos.append(lista_todos_valores[index])
numero_itens_exclusivos = len(lista_valores_unicos)
numero_itens_exclusivos

#Preço médio de compra
preco_medio = purchase_file['Valor'].describe()['mean']

#Número total de compras
numero_compras = purchase_file.shape[0]

#Rendimento total
# Out:
#             Idade     Item ID       Valor
# count  780.000000  780.000000  780.000000
# mean    22.729487   91.293590    2.931192
# std      6.930604   52.707537    1.115780
# min      7.000000    0.000000    1.030000
# 25%     19.000000   44.000000    1.960000
# 50%     22.000000   91.000000    2.880000
# 75%     25.000000  135.000000    3.910000
# max     45.000000  183.000000    4.950000

# %% [markdown]
# ## Análise Demográfica por gênero

# %%
# Implemente aqui sua solução

#Porcentagem e contagem de compradores masculinos, femininos e não informados
lista_compras_sexo = list(purchase_file['Sexo'].values)
lista_sexos = []
for item in lista_compras_sexo:
    if item not in lista_sexos:
        lista_sexos.append(item)
print(lista_sexos)

lista_compradores_masculinos = []
lista_compradores_femininos = []
lista_compradores_nao_informado = []
for index,person in enumerate(lista_consumidores):
    if lista_compras_sexo[index] == 'Masculino' and person not in lista_compradores_masculinos:
        lista_compradores_masculinos.append(person)
    if lista_compras_sexo[index] == 'Feminino' and person not in lista_compradores_femininos:
        lista_compradores_femininos.append(person)
    if lista_compras_sexo[index] == 'Outro / NÃ£o Divulgado' and person not in lista_compradores_nao_informado:
        lista_compradores_nao_informado.append(person)
print(len(lista_compradores_masculinos))
print(len(lista_compradores_femininos))
print(len(lista_compradores_nao_informado))

numero_compradores_masculino = len(lista_compradores_masculinos)
numero_compradores_feminino = len(lista_compradores_femininos)
numero_compradores_nao_informado = len(lista_compradores_nao_informado)
# Out:
# ['Masculino', 'Feminino', 'Outro / NÃ£o Divulgado']
# 465
# 100
# 8

# %% [markdown]
# ## Análise de Compras Por Gênero

# %%
# Implemente aqui sua solução

#Número de compras
numero_compras_gen_masculino = lista_compras_sexo.count('Masculino')
print(numero_compras_gen_masculino)

numero_compras_gen_feminino = lista_compras_sexo.count('Feminino')
print(numero_compras_gen_feminino)

numero_compras_nao_informado = lista_compras_sexo.count('Outro / NÃ£o Divulgado')
print(numero_compras_nao_informado)

#Preço médio de compra
purchase_file['Valor'].describe()

lista_valor_compras_masculinas = []
lista_valor_compras_femininas = []
lista_valor_compras_nao_informado = []
for index,sexo in enumerate(purchase_file['Sexo']):
    if sexo == 'Masculino':
        lista_valor_compras_masculinas.append(purchase_file['Valor'][index])
    if sexo == 'Feminono':
        lista_valor_compras_femininas.append(purchase_file['Valor'][index])
    else:
        lista_valor_compras_nao_informado.append(purchase_file['Valor'][index])

    
#Valor Total de Compra


#Compras for faixa etária
# Out:
# 633
# 136
# 11

# %% [markdown]
# ## Consumidores Mais Populares (Top 5)

# %%
# Implemente aqui sua solução

# %% [markdown]
# ## Itens Mais Populares

# %%
# Implemente aqui sua solução

# %% [markdown]
# ## Itens Mais Lucrativos

# %%
# Implemente aqui sua solução

# %% [markdown]
# ## Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
